# %%
import pandas as pd

# %%
df = pd.read_csv("Potential Candidates - Sheet1.csv")

# %%
df.head()
# Out:
#         State  Position              Name  Birth Date  \
# 0  California   Senator  Dianne Feinstein        1933
# 1  California  Governor       Jerry Brown        1938
# 2     Vermont   Senator     Patrick Leahy        1940
# 3     Vermont   Senator    Bernie Sanders        1941
# 4     Florida   Senator       Bill Nelson        1942
#
#                                       Career  \
# 0             Non-profit organization fellow
# 1                                        NaN
# 2                       Lawyer in a law firm
# 3  Filmmaker Carpenter\n Writer\n Researcher
# 4                 Lawyer in private practice
#
#                              Prior public experience  Inauguration  \
# 0  San Francisco Mayor\n San Francisco Board of S...         33918
# 1  Governor (1975–1983), Attorney General,\n Mayo...         40546
# 2                 Chittenden County State's Attorney         27397
# 3                      U.S. House\n Burlington Mayor         39085
# ...

# %%
df = df[df['Age in 2020'] <= 70]

# %%
df.shape
# Out:
# (45, 14)

# %%
df = df[df['Google Search results'] >= 1000000]
df.sort_values('Google Search results', ascending=False)
# Out:
#          State  Position              Name  Birth Date  \
# 19    New York   Senator     Chuck Schumer        1950
# 20  Washington   Senator      Patty Murray        1950
# 26    Virginia   Senator       Mark Warner        1954
# 50   Wisconsin   Senator     Tammy Baldwin        1962
# 27     Alabama   Senator     Doug Jones[d]        1954
# 52  California   Senator     Kamala Harris        1964
# 22  Washington  Governor        Jay Inslee        1951
# 25    Missouri   Senator  Claire McCaskill        1953
#
#                                          Career  \
# 19                                     Attorney
# 20                             Teacher Lobbyist
# 26               Businessman Venture capitalist
# 50                   Lawyer in private practice
# 27  Senate staffer\n Lawyer in private practice
# 52                                     Attorney
# 22                                          NaN
# 25                                 Trial lawyer
#
# ...

# %%
df.sort_values('Average', ascending=False)
# Out:
#          State  Position              Name  Birth Date  \
# 19    New York   Senator     Chuck Schumer        1950
# 20  Washington   Senator      Patty Murray        1950
# 26    Virginia   Senator       Mark Warner        1954
# 52  California   Senator     Kamala Harris        1964
# 50   Wisconsin   Senator     Tammy Baldwin        1962
# 25    Missouri   Senator  Claire McCaskill        1953
# 27     Alabama   Senator     Doug Jones[d]        1954
# 22  Washington  Governor        Jay Inslee        1951
#
#                                          Career  \
# 19                                     Attorney
# 20                             Teacher Lobbyist
# 26               Businessman Venture capitalist
# 52                                     Attorney
# 50                   Lawyer in private practice
# 25                                 Trial lawyer
# 27  Senate staffer\n Lawyer in private practice
# 22                                          NaN
#
# ...

# %%
df.sort_values('Twitter followers', ascending=False)
# Out:
#          State  Position              Name  Birth Date  \
# 52  California   Senator     Kamala Harris        1964
# 19    New York   Senator     Chuck Schumer        1950
# 25    Missouri   Senator  Claire McCaskill        1953
# 20  Washington   Senator      Patty Murray        1950
# 26    Virginia   Senator       Mark Warner        1954
# 50   Wisconsin   Senator     Tammy Baldwin        1962
# 22  Washington  Governor        Jay Inslee        1951
# 27     Alabama   Senator     Doug Jones[d]        1954
#
#                                          Career  \
# 52                                     Attorney
# 19                                     Attorney
# 25                                 Trial lawyer
# 20                             Teacher Lobbyist
# 26               Businessman Venture capitalist
# 50                   Lawyer in private practice
# 22                                          NaN
# 27  Senate staffer\n Lawyer in private practice
#
# ...
